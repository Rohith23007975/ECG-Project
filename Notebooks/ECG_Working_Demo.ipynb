# %% [markdown]
# # ECG Arrhythmia Detection (Demo)
#
# This notebook demonstrates ECG inference using our trained deep learning model.
# Upload an ECG signal and receive automatic arrhythmia classification.

# %%
ecg_file = "../ecg_sample.csv"

# %%
import sys
import os

# Get the absolute path of the Scripts folder
PROJECT_ROOT = os.path.abspath("..")  # assuming notebooks/ is inside project/
SCRIPTS_PATH = os.path.join(PROJECT_ROOT, "Scripts")

# Add to sys.path if not already
if SCRIPTS_PATH not in sys.path:
    sys.path.append(SCRIPTS_PATH)

print("Scripts folder added to path:", SCRIPTS_PATH)
# Out:
# Scripts folder added to path: C:\Users\Shush\Documents\ECG Project\Scripts

# %%
from sampledep import run_ecg_inference
result = run_ecg_inference(ecg_file)
result
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# {'predicted_label': 'S',
#  'confidence': 97.09,
#  'beat_distribution': {'S': 2234, 'N': 36, 'V': 1}}
